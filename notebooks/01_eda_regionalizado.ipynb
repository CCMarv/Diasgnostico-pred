# %% [markdown]
# # EDA Regionalizado CDC ↔ ENSANUT\n\nNotebook guía de Sprint 2 para análisis exploratorio con enfoque IMSS/ENSANUT.

# %% [markdown]
# ## Bloque 1 — Carga y contrato de calidad\n- Verificar 21 columnas CDC\n- Valores faltantes\n- Distribución de `Diabetes_binary`

# %%
import pandas as pd\nfrom config import COLUMNAS_CDC, COLUMNA_OBJETIVO, RUTA_DATASET_PREDETERMINADA\n\ndf = pd.read_csv(RUTA_DATASET_PREDETERMINADA)\nassert set(COLUMNAS_CDC).issubset(df.columns)

# %% [markdown]
# ## Bloque 2 — Análisis univariado con anotación ENSANUT\nComparar prevalencias CDC vs México por variable binaria y distribuciones continuas.

# %% [markdown]
# ## Bloque 3 — Análisis bivariado\nCorrelación Spearman, odds ratios y contraste por clase.

# %% [markdown]
# ## Bloque 4 — Contraste México vs EE.UU.\nTabla/figura de variables más sesgadas (>30% diferencia relativa).

# %% [markdown]
# ## Bloque 5 — Desbalance y remuestreo\nComparar sin remuestreo, SMOTE y submuestreo con ROC-AUC.

# %% [markdown]
# ## Bloque 6 — Conclusiones\nDocumentar decisiones de preprocesamiento e hipótesis para Sprint 3.
